# %%
import pickle

# %%
with open('../result/서울특별시_turns_1000.pkl', 'rb') as file:
    data = pickle.load(file)

data
# Out:
# array([ 8, 11,  4, 11,  2,  4,  6,  4,  5, 12, 10, 16,  4, 11, 10,  7,  5,
#        22, 11, 20, 26, 10,  8, 18, 13,  4,  7, 14,  5,  9, 20, 12,  7, 17,
#         8, 13, 13, 20,  4,  9, 16, 10, 24,  9,  9, 14,  5,  4, 11, 11, 14,
#        12, 14, 21, 13,  6,  8, 11,  8,  5, 11, 11,  5, 12,  3, 19, 13,  7,
#         8,  9, 16,  9,  7,  8,  8, 16,  6, 23,  6,  9,  6, 10,  4, 28, 11,
#        15, 10,  7, 16, 17, 10,  4,  7, 10,  8, 12, 12, 11, 10, 12, 26, 10,
#        14, 11, 11,  7,  9, 13,  7,  5, 12,  7, 20,  8,  6,  3, 12,  6,  9,
#         9, 11,  4,  3, 10, 11,  6, 17, 14,  2,  9,  6, 16,  6,  9, 17, 10,
#        20, 14, 14, 12,  8, 14, 17,  3, 14, 13, 11,  4,  8,  4,  9,  6, 12,
#         4,  9, 15,  9,  9, 14,  6, 13,  7,  9, 18,  9,  7, 10,  6,  8,  7,
#        14, 15, 15,  4, 11, 17, 14,  3, 13,  3,  8, 11,  9, 11, 15,  9, 14,
#         6,  5, 10, 11,  5, 14, 14, 14, 24,  3, 10, 17, 10,  6,  7,  7, 11,
# ...
